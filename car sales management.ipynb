# %%
# seconds car app
print("--------WELCOME TO THE SECONDS CAR UNIVERSE---------")
x=True
while x:
    print()
    print("CUSTOMER DETAILS")
    print()
    name=input("NAME:").upper()
    loc=input("YOUR CURRENT LOCATION:").upper()
    e_m=input("VALID MAIL_ID:")
    if '@gmail.com' in e_m:
        mob=input("MOBILE NUMBER:")
        if len(mob)==10:
            print()
            print("----------THANK YOU FOR YOUR REGISTRATION--------------")
            x=False
        else:
            print("INVALID MOBILE NUMBER")
            x=True
    else:
        print("INVALID EMAIL-ID")
        x=True
z=True
while z:
    print()
    print("---------CHOOSE YOUR PREFERED CARS LOCATION-----------")
    print()
    s=['Used Cars in Agra','Used Cars in Bangalore','Used Cars in Hyderabad','Used Cars in Chennai','Used Cars in Kerala','Used Cars in Coimbatore',
      'Used Cars in Delhi','Used Cars in Pondichery','Used Cars in Mumbai','Used Cars in Madurai']
    for i in s:
        print(i)
    print()
    x=input("PREFERED LOCATION CARS:")
    if x not in s:
        print("INVALID LOCATION! CHOOSE THE LOCATION FROM THE ABOVE LIST")
        z=True
    else:
        print("-----------THANK YOU FOR YOUR PREFERENCE--------------")
        z=False
class car:
    def sel(self):
        print("---------CARS-----")
        self.cho=['BALENO ZETS AGS','IGNIS ZETA','WAGON R ZXI','S-CROSS ZETA','VITARA BREZZA ZDI+','SWIFT ZXI','BALENO DELTA','CIAZ AUTOMATIC ZXI+',
             'CELERIO VXI AMT','ALTO 800 VXI','CELERIO VXI','ALTO 800 VXI(BLUE)','RITZ VXI','ALTO LXI','EECO 5-STR','WAGON R VXI AMT',
                 'SWIFT DZIRE VDI','ALTO K10 VXI','A-STAR LXI','CELERIO TOUR H2','SWIFT DZIRE TOUR','RITZ VDI','X16 ALPHA','IGNIS SIGMA',
                 'BALENO ALPHA']
        c=1
        for i in self.cho:
            print(c,'.',i)
            c=c+1
        g=True
        while g:
            self.choice=input("CHOOSE CAR FROM THE ABOVE TO SHOW DETAILS").upper()
            if self.choice in self.cho:
                if self.choice == "BALENO ZETS AGS":
                    st={
                        'MODEL_NAME':"BALENO ZETS AGS",
                        'PRICE':'9,20,000',
                        'OWNER':'1ST OWNER',
                        'TRANSMISSION':'AUTOMATIC',
                        'FUEL':'PETROL',
                        'KM DRIVEN':'10,933KM',
                        'YEAR':'2023'
                    }
                    for j in st:
                        print(j,':',st[j])
                    self.bal=920000
                    print("!!!!IF YOUR READY TO PAY NET CASH CONTACT THE OWNER!!!!!")
                    print("------------EMI DETAILS---------")
                    print("MINIMUM INITIAL AMOUNT YOU HAVE TO PAY 100000 to 300000")
                    self.payment=int(input("INITAIL AMOUNT:"))
                    if self.payment>=100000 and self.payment<=300000:
                        self.balance=self.bal-self.payment
                        print("BALANCE AMOUNT",self.balance)
                        self.mon=int(input('HOW MANY MONTH:'))
                        print("MONTH",self.mon)
                        self.final=self.balance/self.mon
                        print("YOU HAVE TO PAY MONTHLY",self.final)
                    else:
                        print("SORRY")
                elif self.choice == 'IGNIS ZETA':
                    s1={
                        'MODEL_NAME':'IGNIS ZETA',
                        'PRICE':'5,50,000',
                        'OWNER':'1ST OWNER',
                        'TRANSMISSION':'MANUAL',
                        'FUEL':'PETROL',
                        'KM DRIVEN':'51,897KM',
                        'YEAR':'2022'
                    }
                    for a in s1:
                        print(a,':',s1[a])
                    self.bal=550000
                    print("!!!!IF YOUR READY TO PAY NET CASH CONTACT THE OWNER!!!!!")
                    print("------------EMI DETAILS---------")
                    print("MINIMUM INITIAL AMOUNT YOU HAVE TO PAY 100000 to 200000")
                    self.payment=int(input("INITAIL AMOUNT:"))
                    if self.payment>=100000 and self.payment<=200000:
                        self.balance=self.bal-self.payment
                        print("BALANCE AMOUNT",self.balance)
                        self.mon=int(input('HOW MANY MONTH:'))
                        print("MONTH",self.mon)
                        self.final=self.balance/self.mon
                        print("YOU HAVE TO PAY MONTHLY",self.final)
                    else:
                        print("SORRY")
                    
                elif self.choice == 'WAGON R ZXI':
                    s2={
                        'MODEL_NAME':'WAGON R ZXI',
                        'PRICE':'5,50,000',
                        'OWNER':'1ST OWNER',
                        'TRANSMISSION':'MANUAL',
                        'FUEL':'PETROL',
                        'KM DRIVEN':'62,041KM',
                        'YEAR':'2020' 
                    }
                    for b in s2:
                         print(b,':',s2[b])
                    self.bal=550000
                    print("!!!!IF YOUR READY TO PAY NET CASH CONTACT THE OWNER!!!!!")
                    print("------------EMI DETAILS---------")
                    print("MINIMUM INITIAL AMOUNT YOU HAVE TO PAY 100000 to 200000")
                    self.payment=int(input("INITAIL AMOUNT:"))
                    if self.payment>=100000 and self.payment<=200000:
                        self.balance=self.bal-self.payment
                        print("BALANCE AMOUNT",self.balance)
                        self.mon=int(input('HOW MANY MONTH:'))
                        print("MONTH",self.mon)
                        self.final=self.balance/self.mon
                        print("YOU HAVE TO PAY MONTHLY",self.final)
                    else:
                        print("SORRY")
                elif self.choice == 'S-CROSS ZETA':
                    s3={
                        'MODEL_NAME':'S-CROSS ZETA',
                        'PRICE':'7,60,000',
                        'OWNER':'1ST OWNER',
                        'TRANSMISSION':'MANUAL',
                        'FUEL':'DIESEL',
                        'KM DRIVEN':'1,00,760KM',
                        'YEAR':'2018'   
                    }
                    for c in s3:
                         print(c,':',s3[c])
                    self.bal=760000
                    print("!!!!IF YOUR READY TO PAY NET CASH CONTACT THE OWNER!!!!!")
                    print("------------EMI DETAILS---------")
                    print("MINIMUM INITIAL AMOUNT YOU HAVE TO PAY 100000 to 300000")
                    self.payment=int(input("INITAIL AMOUNT:"))
                    if self.payment>=100000 and self.payment<=300000:
                        self.balance=self.bal-self.payment
                        print("BALANCE AMOUNT",self.balance)
                        self.mon=int(input('HOW MANY MONTH:'))
                        print("MONTH",self.mon)
                        self.final=self.balance/self.mon
                        print("YOU HAVE TO PAY MONTHLY",self.final)
                    else:
                        print("SORRY")
                elif self.choice == 'VITARA BREZZA ZDI+':
                    s4={
                        'MODEL_NAME':'VITARA BREZZA ZDI+',
                        'PRICE':'8,70,000',
                        'OWNER':'1ST OWNER',
                        'TRANSMISSION':'MANUAL',
                        'FUEL':'DIESEL',
                        'KM DRIVEN':'58,569KM',
                        'YEAR':'2018'   
                    }
                    for d in s4:
                         print(d,':',s4[d])
                    self.bal=870000
                    print("!!!!IF YOUR READY TO PAY NET CASH CONTACT THE OWNER!!!!!")
                    print("------------EMI DETAILS---------")
                    print("MINIMUM INITIAL AMOUNT YOU HAVE TO PAY 100000 to 300000")
                    self.payment=int(input("INITAIL AMOUNT:"))
                    if self.payment>=100000 and self.payment<=300000:
                        self.balance=self.bal-self.payment
                        print("BALANCE AMOUNT",self.balance)
                        self.mon=int(input('HOW MANY MONTH:'))
                        print("MONTH",self.mon)
                        self.final=self.balance/self.mon
                        print("YOU HAVE TO PAY MONTHLY",self.final)
                    else:
                        print("SORRY")
                elif self.choice == "SWIFT ZXI":
                    s5={
                        'MODEL_NAME':'SWIFT ZXI',
                        'PRICE':'5,20,000',
                        'OWNER':'1ST OWNER',
                        'TRANSMISSION':'MANUAL',
                        'FUEL':'DIESEL',
                        'KM DRIVEN':'35,953KM',
                        'YEAR':'2017'
                    }
                    for e in s5:
                         print(e,':',s5[e])
                    self.bal=520000
                    print("!!!!IF YOUR READY TO PAY NET CASH CONTACT THE OWNER!!!!!")
                    print("------------EMI DETAILS---------")
                    print("MINIMUM INITIAL AMOUNT YOU HAVE TO PAY 100000 to 200000")
                    self.payment=int(input("INITAIL AMOUNT:"))
                    if self.payment>=100000 and self.payment<=200000:
                        self.balance=self.bal-self.payment
                        print("BALANCE AMOUNT",self.balance)
                        self.mon=int(input('HOW MANY MONTH:'))
                        print("MONTH",self.mon)
                        self.final=self.balance/self.mon
                        print("YOU HAVE TO PAY MONTHLY",self.final)
                    else:
                        print("SORRY")
                elif self.choice == 'BALENO DELTA':
                    s6={
                        'MODEL_NAME':'BALENO DELTA',
                        'PRICE':'5,20,000',
                        'OWNER':'1ST OWNER',
                        'TRANSMISSION':'MANUAL',
                        'FUEL':'PETROL',
                        'KM DRIVEN':'70,507KM',
                        'YEAR':'2017'
                    }
                    for f in s6:
                         print(f,':',s6[f])
                    self.bal=520000
                    print("!!!!IF YOUR READY TO PAY NET CASH CONTACT THE OWNER!!!!!")
                    print("------------EMI DETAILS---------")
                    print("MINIMUM INITIAL AMOUNT YOU HAVE TO PAY 100000 to 200000")
                    self.payment=int(input("INITAIL AMOUNT:"))
                    if self.payment>=100000 and self.payment<=200000:
                        self.balance=self.bal-self.payment
                        print("BALANCE AMOUNT",self.balance)
                        self.mon=int(input('HOW MANY MONTH:'))
                        print("MONTH",self.mon)
                        self.final=self.balance/self.mon
                        print("YOU HAVE TO PAY MONTHLY",self.final)
                    else:
                        print("SORRY")
                elif self.choice == 'CIAZ AUTOMATIC ZXI+':
                    s7={
                        'MODEL_NAME':'CIAZ AUTOMATIC ZXI+',
                        'PRICE':'5,65,000',
                        'OWNER':'1ST OWNER',
                        'TRANSMISSION':'AUTOMATIC',
                        'FUEL':'PETROL',
                        'KM DRIVEN':'91,017KM',
                        'YEAR':'2016'
                    }
                    for h in s7:
                         print(h,':',s7[h])
                    self.bal=565000
                    print("!!!!IF YOUR READY TO PAY NET CASH CONTACT THE OWNER!!!!!")
                    print("------------EMI DETAILS---------")
                    print("MINIMUM INITIAL AMOUNT YOU HAVE TO PAY 100000 to 200000")
                    self.payment=int(input("INITAIL AMOUNT:"))
                    if self.payment>=100000 and self.payment<=200000:
                        self.balance=self.bal-self.payment
                        print("BALANCE AMOUNT",self.balance)
                        self.mon=int(input('HOW MANY MONTH:'))
                        print("MONTH",self.mon)
                        self.final=self.balance/self.mon
                        print("YOU HAVE TO PAY MONTHLY",self.final)
                    else:
                        print("SORRY")
                elif self.choice == 'CELERIO VXI AMT':
                    s8={
                        'MODEL_NAME':'CELERIO VXI AMT',
                        'PRICE':'4,00,000',
                        'OWNER':'1ST OWNER',
                        'TRANSMISSION':'AUTOMATIC',
                        'FUEL':'PETROL',
                        'KM DRIVEN':'37,016KM',
                        'YEAR':'2016'
                    }
                    for e1 in s8:
                         print(e1,':',s8[e1])
                    self.bal=400000
                    print("!!!!IF YOUR READY TO PAY NET CASH CONTACT THE OWNER!!!!!")
                    print("------------EMI DETAILS---------")
                    print("MINIMUM INITIAL AMOUNT YOU HAVE TO PAY 100000 to 200000")
                    self.payment=int(input("INITAIL AMOUNT:"))
                    if self.payment>=100000 and self.payment<=200000:
                        self.balance=self.bal-self.payment
                        print("BALANCE AMOUNT",self.balance)
                        self.mon=int(input('HOW MANY MONTH:'))
                        print("MONTH",self.mon)
                        self.final=self.balance/self.mon
                        print("YOU HAVE TO PAY MONTHLY",self.final)
                    else:
                        print("SORRY")
                elif self.choice == 'ALTO 800 VXI':
                    s9={
                        'MODEL_NAME':'ALTO 800 VXI',
                        'PRICE':'2,85,000',
                        'OWNER':'1ST OWNER',
                        'TRANSMISSION':'MANUAL',
                        'FUEL':'PETROL',
                        'KM DRIVEN':'59,016KM',
                        'YEAR':'2016'
                    }
                    for e2 in s9:
                         print(e2,':',s9[e2])
                    self.bal=285000
                    print("!!!!IF YOUR READY TO PAY NET CASH CONTACT THE OWNER!!!!!")
                    print("------------EMI DETAILS---------")
                    print("MINIMUM INITIAL AMOUNT YOU HAVE TO PAY 50000 to 100000 ")
                    self.payment=int(input("INITAIL AMOUNT:"))
                    if self.payment>=50000 and self.payment<=100000:
                        self.balance=self.bal-self.payment
                        print("BALANCE AMOUNT",self.balance)
                        self.mon=int(input('HOW MANY MONTH:'))
                        print("MONTH",self.mon)
                        self.final=self.balance/self.mon
                        print("YOU HAVE TO PAY MONTHLY",self.final)
                    else:
                        print("SORRY")
                elif self.choice  == 'CELERIO VXI':
                    s0={
                        'MODEL_NAME':'CELERIO VXI',
                        'PRICE':'3,45,000',
                        'OWNER':'1ST OWNER',
                        'TRANSMISSION':'MANUAL',
                        'FUEL':'PETROL',
                        'KM DRIVEN':'95,814KM',
                        'YEAR':'2016'
                    }
                    for e3 in s0:
                         print(e3,':',s0[e3])
                    self.bal=345000
                    print("!!!!IF YOUR READY TO PAY NET CASH CONTACT THE OWNER!!!!!")
                    print("------------EMI DETAILS---------")
                    print("MINIMUM INITIAL AMOUNT YOU HAVE TO PAY 50000 to 100000")
                    self.payment=int(input("INITAIL AMOUNT:"))
                    if self.payment>=50000 and self.payment<=100000:
                        self.balance=self.bal-self.payment
                        print("BALANCE AMOUNT",self.balance)
                        self.mon=int(input('HOW MANY MONTH:'))
                        print("MONTH",self.mon)
                        self.final=self.balance/self.mon
                        print("YOU HAVE TO PAY MONTHLY",self.final)
                    else:
                        print("SORRY")
                elif self.choice == 'ALTO 800 VXI(BLUE)':
                    a1={
                        'MODEL_NAME':'ALTO 800 VXI(BLUE)',
                        'PRICE':'3,00,000',
                        'OWNER':'1ST OWNER',
                        'TRANSMISSION':'MANUAL',
                        'FUEL':'PETROL',
                        'KM DRIVEN':'37,814KM',
                        'YEAR':'2016'
                    }
                    for e4 in a1:
                         print(e4,':',a1[e4])
                    self.bal=300000
                    print("!!!!IF YOUR READY TO PAY NET CASH CONTACT THE OWNER!!!!!")
                    print("------------EMI DETAILS---------")
                    print("MINIMUM INITIAL AMOUNT YOU HAVE TO PAY 50000 to 100000")
                    self.payment=int(input("INITAIL AMOUNT:"))
                    if self.payment>=50000 and self.payment<=100000:
                        self.balance=self.bal-self.payment
                        print("BALANCE AMOUNT",self.balance)
                        self.mon=int(input('HOW MANY MONTH:'))
                        print("MONTH",self.mon)
                        self.final=self.balance/self.mon
                        print("YOU HAVE TO PAY MONTHLY",self.final)
                    else:
                        print("SORRY")
                elif self.choice == 'RITZ VXI':
                    a2={
                        'MODEL_NAME':'RITZ VXI',
                        'PRICE':'2,00,000',
                        'OWNER':'1ST OWNER',
                        'TRANSMISSION':'MANUAL',
                        'FUEL':'PETROL',
                        'KM DRIVEN':'1,11,605KM',
                        'YEAR':'2010'
                    }
                    for e5 in a2:
                         print(e5,':',a2[e5])
                    self.bal=200000
                    print("!!!!IF YOUR READY TO PAY NET CASH CONTACT THE OWNER!!!!!")
                    print("------------EMI DETAILS---------")
                    print("MINIMUM INITIAL AMOUNT YOU HAVE TO PAY 10000 to 50000")
                    self.payment=int(input("INITAIL AMOUNT:"))
                    if self.payment>=10000 and self.payment<=50000:
                        self.balance=self.bal-self.payment
                        print("BALANCE AMOUNT",self.balance)
                        self.mon=int(input('HOW MANY MONTH:'))
                        print("MONTH",self.mon)
                        self.final=self.balance/self.mon
                        print("YOU HAVE TO PAY MONTHLY",self.final)
                    else:
                        print("SORRY")
                elif self.choice == 'ALTO LXI':
                    a3={
                        'MODEL_NAME':'ALTO LXI',
                        'PRICE':'1,50,000',
                        'OWNER':'1ST OWNER',
                        'TRANSMISSION':'MANUAL',
                        'FUEL':'PETROL',
                        'KM DRIVEN':'66,711KM',
                        'YEAR':'2008'
                    }
                    for e6 in a3:
                         print(e6,':',a3[e6])
                    self.bal=150000
                    print("!!!!IF YOUR READY TO PAY NET CASH CONTACT THE OWNER!!!!!")
                    print("------------EMI DETAILS---------")
                    print("MINIMUM INITIAL AMOUNT YOU HAVE TO PAY 10000 to 30000")
                    self.payment=int(input("INITAIL AMOUNT:"))
                    if self.payment>=10000 and self.payment<=30000:
                        self.balance=self.bal-self.payment
                        print("BALANCE AMOUNT",self.balance)
                        self.mon=int(input('HOW MANY MONTH:'))
                        print("MONTH",self.mon)
                        self.final=self.balance/self.mon
                        print("YOU HAVE TO PAY MONTHLY",self.final)
                    else:
                        print("SORRY")
                elif self.choice == 'EECO 5-STR':
                    a4={
                        'MODEL_NAME':'EECO 5-STR',
                        'PRICE':'5,50,000',
                        'OWNER':'1ST OWNER',
                        'TRANSMISSION':'MANUAL',
                        'FUEL':'PETROL',
                        'KM DRIVEN':'21,411KM',
                        'YEAR':'2022'
                    }
                    for e7 in a4:
                         print(e7,':',a4[e7])
                    self.bal=550000
                    print("!!!!IF YOUR READY TO PAY NET CASH CONTACT THE OWNER!!!!!")
                    print("------------EMI DETAILS---------")
                    print("MINIMUM INITIAL AMOUNT YOU HAVE TO PAY 100000 to 400000")
                    self.payment=int(input("INITAIL AMOUNT:"))
                    if self.payment>=50000 and self.payment<=100000:
                        self.balance=self.bal-self.payment
                        print("BALANCE AMOUNT",self.balance)
                        self.mon=int(input('HOW MANY MONTH:'))
                        print("MONTH",self.mon)
                        self.final=self.balance/self.mon
                        print("YOU HAVE TO PAY MONTHLY",self.final)
                    else:
                        print("SORRY")
                elif self.choice == 'WAGON R VXI AMT':
                    a5={
                        'MODEL_NAME':'WAGON R VXI AMT',
                        'PRICE':'4,50,000',
                        'OWNER':'1ST OWNER',
                        'TRANSMISSION':'AUTOMATIC',
                        'FUEL':'PETROL',
                        'KM DRIVEN':'12,411KM',
                        'YEAR':'2017'
                    }
                    for e8 in a5:
                         print(e8,':',a5[e8])
                    self.bal=450000
                    print("!!!!IF YOUR READY TO PAY NET CASH CONTACT THE OWNER!!!!!")
                    print("------------EMI DETAILS---------")
                    print("MINIMUM INITIAL AMOUNT YOU HAVE TO PAY 100000 to 400000")
                    self.payment=int(input("INITAIL AMOUNT:"))
                    if self.payment>=50000 and self.payment<=100000:
                        self.balance=self.bal-self.payment
                        print("BALANCE AMOUNT",self.balance)
                        self.mon=int(input('HOW MANY MONTH:'))
                        print("MONTH",self.mon)
                        self.final=self.balance/self.mon
                        print("YOU HAVE TO PAY MONTHLY",self.final)
                    else:
                        print("SORRY")
                elif self.choice == 'SWIFT DZIRE VDI':
                    a6={
                        'MODEL_NAME':'SWIFT DZIRE VDI',
                        'PRICE':'3,25,000',
                        'OWNER':'1ST OWNER',
                        'TRANSMISSION':'MANUAL',
                        'FUEL':'DIESEL',
                        'KM DRIVEN':'1,57,277KM',
                        'YEAR':'2013'
                    }
                    for e9 in a6:
                         print(e9,':',a6[e9])
                    self.bal=325000
                    print("!!!!IF YOUR READY TO PAY NET CASH CONTACT THE OWNER!!!!!")
                    print("------------EMI DETAILS---------")
                    print("MINIMUM INITIAL AMOUNT YOU HAVE TO PAY 100000 to 400000")
                    self.payment=int(input("INITAIL AMOUNT:"))
                    if self.payment>=10000 and self.payment<=30000:
                        self.balance=self.bal-self.payment
                        print("BALANCE AMOUNT",self.balance)
                        self.mon=int(input('HOW MANY MONTH:'))
                        print("MONTH",self.mon)
                        self.final=self.balance/self.mon
                        print("YOU HAVE TO PAY MONTHLY",self.final)
                    else:
                        print("SORRY")
                elif self.choice == 'ALTO K10 VXI':
                    a7={
                        'MODEL_NAME':'ALTO K10 VXI',
                        'PRICE':'2,00,000',
                        'OWNER':'2ND OWNER',
                        'TRANSMISSION':'MANUAL',
                        'FUEL':'PETROL',
                        'KM DRIVEN':'64,663KM',
                        'YEAR':'2012'
                    }
                    for h1 in a7:
                         print(h1,':',a7[h1])
                    self.bal=200000
                    print("!!!!IF YOUR READY TO PAY NET CASH CONTACT THE OWNER!!!!!")
                    print("------------EMI DETAILS---------")
                    print("MINIMUM INITIAL AMOUNT YOU HAVE TO PAY 10000 to 30000")
                    self.payment=int(input("INITAIL AMOUNT:"))
                    if self.payment>=10000 and self.payment<=30000:
                        self.balance=self.bal-self.payment
                        print("BALANCE AMOUNT",self.balance)
                        self.mon=int(input('HOW MANY MONTH:'))
                        print("MONTH",self.mon)
                        self.final=self.balance/self.mon
                        print("YOU HAVE TO PAY MONTHLY",self.final)
                    else:
                        print("SORRY")
                elif self.choice == 'A-STAR LXI':
                    a8={
                        'MODEL_NAME':'A-STAR LXI',
                        'PRICE':'1,50,000',
                        'OWNER':'1ST OWNER',
                        'TRANSMISSION':'MANUAL',
                        'FUEL':'PETROL',
                        'KM DRIVEN':'26,663KM',
                        'YEAR':'2010'
                    }
                    for h2 in a8:
                         print(h2,':',a8[h2])
                    self.bal=10000
                    print("!!!!IF YOUR READY TO PAY NET CASH CONTACT THE OWNER!!!!!")
                    print("------------EMI DETAILS---------")
                    print("MINIMUM INITIAL AMOUNT YOU HAVE TO PAY 10000 to 30000")
                    self.payment=int(input("INITAIL AMOUNT:"))
                    if self.payment>=10000 and self.payment<=30000:
                        self.balance=self.bal-self.payment
                        print("BALANCE AMOUNT",self.balance)
                        self.mon=int(input('HOW MANY MONTH:'))
                        print("MONTH",self.mon)
                        self.final=self.balance/self.mon
                        print("YOU HAVE TO PAY MONTHLY",self.final)
                    else:
                        print("SORRY")
                elif self.choice == 'CELERIO TOUR H2':
                    a9={
                        'MODEL_NAME':'CELERIO TOUR H2',
                        'PRICE':'4,60,000',
                        'OWNER':'1ST OWNER',
                        'TRANSMISSION':'MANUAL',
                        'FUEL':'PETROL',
                        'KM DRIVEN':'21,410KM',
                        'YEAR':'2021'
                    }
                    for h3 in a9:
                         print(h3,':',a9[h3])
                    self.bal=460000
                    print("!!!!IF YOUR READY TO PAY NET CASH CONTACT THE OWNER!!!!!")
                    print("------------EMI DETAILS---------")
                    print("MINIMUM INITIAL AMOUNT YOU HAVE TO PAY 50000 to 100000")
                    self.payment=int(input("INITAIL AMOUNT:"))
                    if self.payment>=50000 and self.payment<=10000:
                        self.balance=self.bal-self.payment
                        print("BALANCE AMOUNT",self.balance)
                        self.mon=int(input('HOW MANY MONTH:'))
                        print("MONTH",self.mon)
                        self.final=self.balance/self.mon
                        print("YOU HAVE TO PAY MONTHLY",self.final)
                    else:
                        print("SORRY")
                elif self.choice == 'SWIFT DZIRE TOUR':
                    b1={
                        'MODEL_NAME':'SWIFT DZIRE TOUR',
                        'PRICE':'3,00,000',
                        'OWNER':'2ND OWNER',
                        'TRANSMISSION':'MANUAL',
                        'FUEL':'DIESEL',
                        'KM DRIVEN':'2,00,860KM',
                        'YEAR':'2016'
                    }
                    for h4 in b1:
                         print(h4,':',b1[h4])
                    self.bal=300000
                    print("!!!!IF YOUR READY TO PAY NET CASH CONTACT THE OWNER!!!!!")
                    print("------------EMI DETAILS---------")
                    print("MINIMUM INITIAL AMOUNT YOU HAVE TO PAY 50000 to 100000")
                    self.payment=int(input("INITAIL AMOUNT:"))
                    if self.payment>=50000 and self.payment<=100000:
                        self.balance=self.bal-self.payment
                        print("BALANCE AMOUNT",self.balance)
                        self.mon=int(input('HOW MANY MONTH:'))
                        print("MONTH",self.mon)
                        self.final=self.balance/self.mon
                        print("YOU HAVE TO PAY MONTHLY",self.final)
                    else:
                        print("SORRY")
                elif self.choice == 'RITZ VDI':
                    b2={
                        'MODEL_NAME':'RITZ VDI',
                        'PRICE':'3,00,000',
                        'OWNER':'1ST OWNER',
                        'TRANSMISSION':'MANUAL',
                        'FUEL':'PETROL',
                        'KM DRIVEN':'1,25,969KM',
                        'YEAR':'2013'
                    }
                    for h5 in b2:
                         print(h5,':',b2[h5])
                    self.bal=300000
                    print("!!!!IF YOUR READY TO PAY NET CASH CONTACT THE OWNER!!!!!")
                    print("------------EMI DETAILS---------")
                    print("MINIMUM INITIAL AMOUNT YOU HAVE TO PAY 50000 to 100000")
                    self.payment=int(input("INITAIL AMOUNT:"))
                    if self.payment>=50000 and self.payment<=100000:
                        self.balance=self.bal-self.payment
                        print("BALANCE AMOUNT",self.balance)
                        self.mon=int(input('HOW MANY MONTH:'))
                        print("MONTH",self.mon)
                        self.final=self.balance/self.mon
                        print("YOU HAVE TO PAY MONTHLY",self.final)
                    else:
                        print("SORRY")
                elif self.choice == 'X16 ALPHA':
                    b3={
                        'MODEL_NAME':'X16 ALPHA',
                        'PRICE':'8,00,000',
                        'OWNER':'1ST OWNER',
                        'TRANSMISSION':'MANUAL',
                        'FUEL':'PETROL',
                        'KM DRIVEN':'89,972KM',
                        'YEAR':'2019'
                    }
                    for h6 in b3:
                         print(h6,':',b3[h6])
                    self.bal=800000
                    print("!!!!IF YOUR READY TO PAY NET CASH CONTACT THE OWNER!!!!!")
                    print("------------EMI DETAILS---------")
                    print("MINIMUM INITIAL AMOUNT YOU HAVE TO PAY 100000 to 300000")
                    self.payment=int(input("INITAIL AMOUNT:"))
                    if self.payment>=100000 and self.payment<=300000:
                        self.balance=self.bal-self.payment
                        print("BALANCE AMOUNT",self.balance)
                        self.mon=int(input('HOW MANY MONTH:'))
                        print("MONTH",self.mon)
                        self.final=self.balance/self.mon
                        print("YOU HAVE TO PAY MONTHLY",self.final)
                    else:
                        print("SORRY")
                elif self.choice == 'IGNIS SIGMA':
                    b4={
                        'MODEL_NAME':'IGNIS SIGMA',
                        'PRICE':'4,35,000',
                        'OWNER':'1ST OWNER',
                        'TRANSMISSION':'MANUAL',
                        'FUEL':'PETROL',
                        'KM DRIVEN':'55,972KM',
                        'YEAR':'2018'
                    }
                    for h7 in b4:
                         print(h7,':',b4[h7])
                    self.bal=435000
                    print("!!!!IF YOUR READY TO PAY NET CASH CONTACT THE OWNER!!!!!")
                    print("------------EMI DETAILS---------")
                    print("MINIMUM INITIAL AMOUNT YOU HAVE TO PAY 50000 to 100000")
                    self.payment=int(input("INITAIL AMOUNT:"))
                    if self.payment>=50000 and self.payment<=100000:
                        self.balance=self.bal-self.payment
                        print("BALANCE AMOUNT",self.balance)
                        self.mon=int(input('HOW MANY MONTH:'))
                        print("MONTH",self.mon)
                        self.final=self.balance/self.mon
                        print("YOU HAVE TO PAY MONTHLY",self.final)
                    else:
                        print("SORRY")
                elif self.choice == 'BALENO ALPHA':
                    b5={
                        'MODEL_NAME':'BALENO ALPHA',
                        'PRICE':'5,20,000',
                        'OWNER':'1ST OWNER',
                        'TRANSMISSION':'MANUAL',
                        'FUEL':'PETROL',
                        'KM DRIVEN':'38,936KM',
                        'YEAR':'2015'
                    }
                    for h8 in b5:
                         print(h8,':',b5[h8])
                    self.bal=520000
                    print("!!!!IF YOUR READY TO PAY NET CASH CONTACT THE OWNER!!!!!")
                    print("------------EMI DETAILS---------")
                    print("MINIMUM INITIAL AMOUNT YOU HAVE TO PAY 50000 to 100000")
                    self.payment=int(input("INITAIL AMOUNT:"))
                    if self.payment>=50000 and self.payment<=100000:
                        self.balance=self.bal-self.payment
                        print("BALANCE AMOUNT",self.balance)
                        self.mon=int(input('HOW MANY MONTH:'))
                        print("MONTH",self.mon)
                        self.final=self.balance/self.mon
                        print("YOU HAVE TO PAY MONTHLY",self.final)
                    else:
                        print("SORRY")
                self.rs=input("YOU WANT TO CAR MORE DETAILS?Y/N").upper()
                if self.rs == 'Y':
                    g=True
                elif self.rs == 'N':
                    g=False
                else:
                    print("INVALID OPTION")
            
            else:
                print("INVALID CAR_MODEL!")
                tv=input("YOU WANT TO CONTINUEY/N?:").upper()
                if tv == 'Y':
                    g=True
                elif tv == 'N':
                    g=False
cars=car()
cars.sel()
# Out:
# --------WELCOME TO THE SECONDS CAR UNIVERSE---------
#
# CUSTOMER DETAILS
# NAME: RAGHUL
# YOUR CURRENT LOCATION: CHENNAI
# VALID MAIL_ID: raghulkumar3900@gmail.com
# MOBILE NUMBER: 8925476327
# ----------THANK YOU FOR YOUR REGISTRATION--------------
#
# ---------CHOOSE YOUR PREFERED CARS LOCATION-----------
#
# Used Cars in Agra
# Used Cars in Bangalore
# Used Cars in Hyderabad
# Used Cars in Chennai
# Used Cars in Kerala
# Used Cars in Coimbatore
# Used Cars in Delhi
# Used Cars in Pondichery
# Used Cars in Mumbai
# Used Cars in Madurai
# PREFERED LOCATION CARS: Used Cars in Chennai
# -----------THANK YOU FOR YOUR PREFERENCE--------------
# ---------CARS-----
# 1 . BALENO ZETS AGS
# 2 . IGNIS ZETA
# 3 . WAGON R ZXI
# 4 . S-CROSS ZETA
# 5 . VITARA BREZZA ZDI+
# 6 . SWIFT ZXI
# 7 . BALENO DELTA
# 8 . CIAZ AUTOMATIC ZXI+
# 9 . CELERIO VXI AMT
# 10 . ALTO 800 VXI
# 11 . CELERIO VXI
# 12 . ALTO 800 VXI(BLUE)
# 13 . RITZ VXI
# 14 . ALTO LXI
# 15 . EECO 5-STR
# 16 . WAGON R VXI AMT
# ...

# %%
s=input("email:")
c=0
for i in s:
    if i=='@gmail.com':
        c=c+1
if c==1:
    print("val")
else:
    print("in")
# Out:
# email: raghulkumar3900@gmail.com
# in

# %%
s=input()
if '@gmail.com' in s:
    print("valid")
else:
    print("invalid")
# Out:
#  raghulkumar3900@gmail.com
# valid

# %%
s={
    "1":'ram',
    "2":'raj'
}
for i1 in s:
    print(i1,s[i1])
# Out:
# 1 ram
# 2 raj
